# %% [markdown]
# # NFL Sports Betting Algorithm - LASSO Algorithm
#
# #### By Tai Chowdhury

# %%
#Download Important Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from scipy import stats
import warnings
from shapely.geometry import Point
import plotly.express as px
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt
from sklearn.model_selection import ShuffleSplit
from sklearn.utils import resample

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc
from sklearn import metrics

# %%
#Ignore Warnings on final

warnings.filterwarnings('ignore')

#Original Data
df = pd.read_csv("NFL_Data_Correct_3.csv")

# %%
df.head(5)
#df.tail(5)
# Out:
#    Seas  Week Team Opponent Unique_ID Opponent_ID Home/Away  Score  Opp_Score  \
# 0  2018     2  ARI      LAR  2018ARI2    2018LAR2      Away      0         34
# 1  2018     3  ARI      CHI  2018ARI3    2018CHI3      Home     14         16
# 2  2018     4  ARI      SEA  2018ARI4    2018SEA4      Home     17         20
# 3  2018     5  ARI      SFO  2018ARI5    2018SFO5      Away     28         18
# 4  2018     6  ARI      MIN  2018ARI6    2018MIN6      Away     17         27
#
#   W/L  ...  opp_Rec_Drop_Perc  opp_Def_Air  opp_Def_YAC  opp_Def_Blitz  \
# 0   L  ...          11.111111          132          212             15
# 1   L  ...           0.000000          158           68             10
# 2   L  ...          12.500000           81           87             22
# 3   W  ...           8.695652          139          111             11
# 4   L  ...           0.000000          188          123             12
#
#    opp_Def_Hrry  opp_Def_QBKD  opp_Def_Sk.1  opp_Def_Pressure  opp_Def_MTkl  \
# 0             9             0             1                10            11
# 1            11             2             6                19             7
# 2             7             4             5                16             5
# 3             0             1             1                 2            10
# 4             2             0             3                 5             6
#
#    opp_Def_MTkl_Perc
# 0          13.750000
# 1          11.864407
# 2           8.064516
# 3          13.513514
# 4          11.320755
#
# [5 rows x 214 columns]

# %% [markdown]
# ###  Scanning for missing data or null cells

# %%
# summarize the dataset with statistical summary of numeric "float" variables

df.shape
# Out:
# (1376, 214)

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1376 entries, 0 to 1375
# Data columns (total 214 columns):
#  #    Column                   Non-Null Count  Dtype
# ---   ------                   --------------  -----
#  0    Seas                     1376 non-null   int64
#  1    Week                     1376 non-null   int64
#  2    Team                     1376 non-null   object
#  3    Opponent                 1376 non-null   object
#  4    Unique_ID                1376 non-null   object
#  5    Opponent_ID              1376 non-null   object
#  6    Home/Away                1376 non-null   object
#  7    Score                    1376 non-null   int64
#  8    Opp_Score                1376 non-null   int64
#  9    W/L                      1376 non-null   object
#  10   Lag_Score                1376 non-null   int64
#  11   Prev_W/L                 1376 non-null   int64
#  12   Penalties                1376 non-null   int64
#  13   Penalty_Yds              1376 non-null   int64
#  14   Pass_Cmp                 1376 non-null   int64
#  15   Pass_Att                 1376 non-null   int64
#  16   Pass_Yds                 1376 non-null   int64
#  17   Pass_TD                  1376 non-null   float64
#  18   INT_Thrown               1376 non-null   int64
#  19   Sk_Taken                 1376 non-null   float64
#  20   SK_Yds                   1376 non-null   float64
#  21   Pass_Long                1376 non-null   int64
#  22   Passer Rating            1376 non-null   float64
#  23   Rush_Att                 1376 non-null   float64
#  24   Rush_Yds                 1376 non-null   int64
#  25   Rush_TD                  1376 non-null   int64
#  26   Rush_Lng                 1376 non-null   int64
#  27   Rec_Tgt                  1376 non-null   int64
#  28   Receptions               1376 non-null   int64
#  29   Rec_Yds                  1376 non-null   int64
#  30   Rec_TD                   1376 non-null   int64
#  31   Rec_Lng                  1376 non-null   int64
#  32   Fumble_Total             1376 non-null   int64
#  33   Fumbles_Lost             1376 non-null   float64
#  34   Def_INT                  1376 non-null   int64
#  35   Def_INT_Yds              1376 non-null   int64
#  36   Def_INT_TD               1376 non-null   int64
#  37   Def_INT_Lng              1376 non-null   int64
#  38   PD                       1376 non-null   int64
#  39   Def_Sk                   1376 non-null   float64
#  40   Comb_Tkl                 1376 non-null   int64
#  41   Solo_Tkl                 1376 non-null   int64
#  42   Ast_Tkl                  1376 non-null   int64
#  43   TFL                      1376 non-null   int64
#  44   QBHits                   1376 non-null   int64
#  45   Def_FR                   1376 non-null   int64
#  46   Def_FR_Yds               1376 non-null   int64
#  47   Def_FR_TD                1376 non-null   int64
#  48   Force_Fum                1376 non-null   int64
#  49   K_Ret                    1376 non-null   int64
#  50   K_Ret_Yds                1376 non-null   int64
#  51   K_Ret_YPR                1376 non-null   float64
#  52   K_Ret_TD                 1376 non-null   int64
#  53   K_Ret_Lng                1376 non-null   int64
#  54   P_Ret                    1376 non-null   int64
#  55   P_Ret_Yds                1376 non-null   int64
#  56   P_Ret_YPR                1376 non-null   float64
#  57   P_Ret_TD                 1376 non-null   int64
#  58   P_Ret_Lng                1376 non-null   int64
#  59   XPM                      1376 non-null   int64
#  60   XPA                      1376 non-null   int64
#  61   FGM                      1376 non-null   int64
#  62   FGA                      1376 non-null   int64
#  63   Punts                    1376 non-null   int64
#  64   Punt_Yds                 1376 non-null   int64
#  65   Yards_Per_Punt           1376 non-null   float64
#  66   Punt_Lng                 1376 non-null   int64
#  67   P_1D                     1376 non-null   int64
#  68   P_1D_Perc                1376 non-null   float64
#  69   IAY                      1376 non-null   int64
#  70   IAY_Per_Att              1376 non-null   float64
#  71   CAY                      1376 non-null   int64
#  72   CAY_Per_CMP              1376 non-null   float64
#  73   CAY_Per_Att              1376 non-null   float64
#  74   P_YAC                    1376 non-null   int64
#  75   P_YAC_Per_Cmp            1376 non-null   float64
#  76   P_Drops                  1376 non-null   int64
#  77   P_Drop_Perc              1376 non-null   float64
#  78   BadTh                    1376 non-null   int64
#  79   BadTh_Perc               1376 non-null   float64
#  80   Sk_Taken.1               1376 non-null   int64
#  81   QB_Blitzed               1376 non-null   int64
#  82   QB_Hurried               1376 non-null   int64
#  83   QB_Hits                  1376 non-null   int64
#  84   QB_Pressured             1376 non-null   int64
#  85   QB_Pressured_Perc        1376 non-null   float64
#  86   Scrm                     1376 non-null   int64
#  87   Yds_Per_Scrm             1376 non-null   float64
#  88   Rush_1D                  1376 non-null   int64
#  89   Rush_YBC                 1376 non-null   int64
#  90   Rush_YBC_Per_Att         1376 non-null   float64
#  91   Rush_YAC                 1376 non-null   int64
#  92   Rush_YAC_Per_Att         1376 non-null   float64
#  93   Rush_BrkTkl              1376 non-null   int64
#  94   Rush_Att_Per_BrkTkl      1376 non-null   float64
#  95   Rec_1D                   1376 non-null   int64
#  96   Rec_YBC                  1376 non-null   int64
#  97   Rec_YBC_Per_Rec          1376 non-null   float64
#  98   Rec_YAC                  1376 non-null   int64
#  99   Rec_YAC_Per_Rec          1376 non-null   float64
#  100  Rec_BrkTkl               1376 non-null   int64
#  101  Rec_BrkTkl_Per_Rec       1376 non-null   float64
#  102  Rec_Drop                 1376 non-null   int64
#  103  Rec_Drop_Perc            1376 non-null   float64
#  104  Def_Air                  1376 non-null   int64
#  105  Def_YAC                  1376 non-null   int64
#  106  Def_Blitz                1376 non-null   int64
#  107  Def_Hrry                 1376 non-null   int64
#  108  Def_QBKD                 1376 non-null   int64
#  109  Def_Sk.1                 1376 non-null   int64
#  110  Def_Pressure             1376 non-null   int64
#  111  Def_MTkl                 1376 non-null   int64
#  112  Def_MTkl_Perc            1376 non-null   float64
#  113  opp_Penalties            1376 non-null   int64
#  114  opp_Penalty_Yds          1376 non-null   int64
#  115  opp_Pass_Cmp             1376 non-null   int64
#  116  opp_Pass_Att             1376 non-null   int64
#  117  opp_Pass_Yds             1376 non-null   int64
#  118  opp_Pass_TD              1376 non-null   float64
#  119  opp_INT_Thrown           1376 non-null   int64
#  120  opp_Sk_Taken             1376 non-null   float64
#  121  opp_SK_Yds               1376 non-null   float64
#  122  opp_Pass_Long            1376 non-null   int64
#  123  opp_Passer Rating        1376 non-null   float64
#  124  opp_Rush_Att             1376 non-null   float64
#  125  opp_Rush_Yds             1376 non-null   int64
#  126  opp_Rush_TD              1376 non-null   int64
#  127  opp_Rush_Lng             1376 non-null   int64
#  128  opp_Rec_Tgt              1376 non-null   int64
#  129  opp_Receptions           1376 non-null   int64
#  130  opp_Rec_Yds              1376 non-null   int64
#  131  opp_Rec_TD               1376 non-null   int64
#  132  opp_Rec_Lng              1376 non-null   int64
#  133  opp_Fumble_Total         1376 non-null   int64
#  134  opp_Fumbles_Lost         1376 non-null   float64
#  135  opp_Def_INT              1376 non-null   int64
#  136  opp_Def_INT_Yds          1376 non-null   int64
#  137  opp_Def_INT_TD           1376 non-null   int64
#  138  opp_Def_INT_Lng          1376 non-null   int64
#  139  opp_PD                   1376 non-null   int64
#  140  opp_Def_Sk               1376 non-null   float64
#  141  opp_Comb_Tkl             1376 non-null   int64
#  142  opp_Solo_Tkl             1376 non-null   int64
#  143  opp_Ast_Tkl              1376 non-null   int64
#  144  opp_TFL                  1376 non-null   int64
#  145  opp_QBHits               1376 non-null   int64
#  146  opp_Def_FR               1376 non-null   int64
#  147  opp_Def_FR_Yds           1376 non-null   int64
#  148  opp_Def_FR_TD            1376 non-null   int64
#  149  opp_Force_Fum            1376 non-null   int64
#  150  opp_K_Ret                1376 non-null   int64
#  151  opp_K_Ret_Yds            1376 non-null   int64
#  152  opp_K_Ret_YPR            1376 non-null   float64
#  153  opp_K_Ret_TD             1376 non-null   int64
#  154  opp_K_Ret_Lng            1376 non-null   int64
#  155  opp_P_Ret                1376 non-null   int64
#  156  opp_P_Ret_Yds            1376 non-null   int64
#  157  opp_P_Ret_YPR            1376 non-null   float64
#  158  opp_P_Ret_TD             1376 non-null   int64
#  159  opp_P_Ret_Lng            1376 non-null   int64
#  160  opp_XPM                  1376 non-null   int64
#  161  opp_XPA                  1376 non-null   int64
#  162  opp_FGM                  1376 non-null   int64
#  163  opp_FGA                  1376 non-null   int64
#  164  opp_Punts                1376 non-null   int64
#  165  opp_Punt_Yds             1376 non-null   int64
#  166  opp_Yards_Per_Punt       1376 non-null   float64
#  167  opp_Punt_Lng             1376 non-null   int64
#  168  opp_P_1D                 1376 non-null   int64
#  169  opp_P_1D_Perc            1376 non-null   float64
#  170  opp_IAY                  1376 non-null   int64
#  171  opp_IAY_Per_Att          1376 non-null   float64
#  172  opp_CAY                  1376 non-null   int64
#  173  opp_CAY_Per_CMP          1376 non-null   float64
#  174  opp_CAY_Per_Att          1376 non-null   float64
#  175  opp_P_YAC                1376 non-null   int64
#  176  opp_P_YAC_Per_Cmp        1376 non-null   float64
#  177  opp_P_Drops              1376 non-null   int64
#  178  opp_P_Drop_Perc          1376 non-null   float64
#  179  opp_BadTh                1376 non-null   int64
#  180  opp_BadTh_Perc           1376 non-null   float64
#  181  opp_Sk_Taken.1           1376 non-null   int64
#  182  opp_QB_Blitzed           1376 non-null   int64
#  183  opp_QB_Hurried           1376 non-null   int64
#  184  opp_QB_Hits              1376 non-null   int64
#  185  opp_QB_Pressured         1376 non-null   int64
#  186  opp_QB_Pressured_Perc    1376 non-null   float64
#  187  opp_Scrm                 1376 non-null   int64
#  188  opp_Yds_Per_Scrm         1376 non-null   float64
#  189  opp_Rush_1D              1376 non-null   int64
#  190  opp_Rush_YBC             1376 non-null   int64
#  191  opp_Rush_YBC_Per_Att     1376 non-null   float64
#  192  opp_Rush_YAC             1376 non-null   int64
#  193  opp_Rush_YAC_Per_Att     1376 non-null   float64
#  194  opp_Rush_BrkTkl          1376 non-null   int64
#  195  opp_Rush_Att_Per_BrkTkl  1376 non-null   float64
#  196  opp_Rec_1D               1376 non-null   int64
#  197  opp_Rec_YBC              1376 non-null   int64
#  198  opp_Rec_YBC_Per_Rec      1376 non-null   float64
#  199  opp_Rec_YAC              1376 non-null   int64
#  200  opp_Rec_YAC_Per_Rec      1376 non-null   float64
#  201  opp_Rec_BrkTkl           1376 non-null   int64
#  202  opp_Rec_BrkTkl_Per_Rec   1376 non-null   float64
#  203  opp_Rec_Drop             1376 non-null   int64
#  204  opp_Rec_Drop_Perc        1376 non-null   float64
#  205  opp_Def_Air              1376 non-null   int64
#  206  opp_Def_YAC              1376 non-null   int64
#  207  opp_Def_Blitz            1376 non-null   int64
#  208  opp_Def_Hrry             1376 non-null   int64
#  209  opp_Def_QBKD             1376 non-null   int64
#  210  opp_Def_Sk.1             1376 non-null   int64
#  211  opp_Def_Pressure         1376 non-null   int64
#  212  opp_Def_MTkl             1376 non-null   int64
#  213  opp_Def_MTkl_Perc        1376 non-null   float64
# dtypes: float64(54), int64(154), object(6)
# memory usage: 2.2+ MB

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check for null values - We do not have any null values

df.isnull().sum()
# Out:
# Seas                 0
# Week                 0
# Team                 0
# Opponent             0
# Unique_ID            0
#                     ..
# opp_Def_QBKD         0
# opp_Def_Sk.1         0
# opp_Def_Pressure     0
# opp_Def_MTkl         0
# opp_Def_MTkl_Perc    0
# Length: 214, dtype: int64

# %%
df_train = df[df['Seas'] < 2020]
df_train = df_train.sort_values('Seas')
df_train

df_test =df[df['Seas'] == 2020]

# %%
df_train = df_train.drop(columns = ['Seas','Team','Opponent','Home/Away','Unique_ID','Opponent_ID','Opp_Score','W/L'])
df_test = df_test.drop(columns = ['Seas','Team','Opponent','Home/Away','Unique_ID','Opponent_ID','Opp_Score','W/L'])

# %%
X = df_train.loc[:,df_train.columns != 'Score']
y = df_train['Score']

# %%
from sklearn.model_selection import cross_validate

def EvaluateRegressionEstimator(regEstimator, X, y, cv):
    
    scores = cross_validate(regEstimator, X, y, scoring=errorScoring, cv=cv, return_train_score=True)

    #cross val score sign-flips the outputs of MAE
    # https://github.com/scikit-learn/scikit-learn/issues/2439
    scores['test_MAE'] = scores['test_MAE'] * -1
    scores['test_MAPE'] = scores['test_MAPE'] * -1
    scores['test_RMSE'] = scores['test_RMSE'] * -1

    #print mean MAE for all folds 
    maeAvg = scores['test_MAE'].mean()
    print_str = "The average MAE for all cv folds is: \t\t\t {maeAvg:.5}"
    print(print_str.format(maeAvg=maeAvg))

    #print mean test_MAPE for all folds
    scores['test_MAPE'] = scores['test_MAPE']
    mape_avg = scores['test_MAPE'].mean()
    print_str = "The average MAE percentage (MAPE) for all cv folds is: \t {mape_avg:.5}"
    print(print_str.format(mape_avg=mape_avg))

    #print mean MAE for all folds 
    RMSEavg = scores['test_RMSE'].mean()
    print_str = "The average RMSE for all cv folds is: \t\t\t {RMSEavg:.5}"
    print(print_str.format(RMSEavg=RMSEavg))
    print('*********************************************************')

    print('Cross Validation Fold Mean Error Scores')
    scoresResults = pd.DataFrame()
    scoresResults['MAE'] = scores['test_MAE']
    scoresResults['MAPE'] = scores['test_MAPE']
    scoresResults['RMSE'] = scores['test_RMSE']
    return scoresResults

# %%
#Use mean absolute error (MAE) to score the regression models created 
#(the scale of MAE is identical to the response variable)
from sklearn.metrics import mean_absolute_error, make_scorer, mean_squared_error

#Function for Root mean squared error
#https://stackoverflow.com/questions/17197492/root-mean-square-error-in-python
def rmse(y_actual, y_predicted):
    return np.sqrt(mean_squared_error(y_actual, y_predicted))

#Function for Mean Absolute Percentage Error (MAPE) - Untested
#Adapted from - https://stackoverflow.com/questions/42250958/how-to-optimize-mape-code-in-python
def mape(y_actual, y_predicted): 
    mask = y_actual != 0
    return (np.fabs(y_actual - y_predicted)/y_actual)[mask].mean() * 100

#Create scorers for rmse and mape functions
mae_scorer = make_scorer(score_func=mean_absolute_error, greater_is_better=False)
rmse_scorer = make_scorer(score_func=rmse, greater_is_better=False)
mape_scorer = make_scorer(score_func=mape, greater_is_better=False)

#Make scorer array to pass into cross_validate() function for producing mutiple scores for each cv fold.
errorScoring = {'MAE':  mae_scorer, 
                'RMSE': rmse_scorer,
                'MAPE': mape_scorer
               }

# %%
cv = ShuffleSplit(n_splits = 10, test_size = .2, random_state = 27)

# %%
#Create a regression object and perform a grid search to find the best parameters
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import GridSearchCV

lasso_reg = Lasso(fit_intercept=True, normalize=True,copy_X=True
          , max_iter=10000, precompute=True, tol=0.0001, random_state=27)

alpha = [0.001, 0.1, 1, 10, 20]
selection = ['cyclic','random']
warm_start = [True, False]
parameters = {'alpha': alpha, 'selection': selection, 'warm_start': warm_start}

regGridSearch = GridSearchCV(estimator=lasso_reg
                   , n_jobs=8 
                   , verbose=1
                   , param_grid=parameters
                   , cv=cv 
                   , scoring=mae_scorer)

regGridSearch.fit(X, y)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=27, test_size=0.2, train_size=None),
#              estimator=Lasso(max_iter=10000, normalize=True, precompute=True,
#                              random_state=27),
#              n_jobs=8,
#              param_grid={'alpha': [0.001, 0.1, 1, 10, 20],
#                          'selection': ['cyclic', 'random'],
#                          'warm_start': [True, False]},
#              scoring=make_scorer(mean_absolute_error, greater_is_better=False),
#              verbose=1)

# %%
#Display the best estimator parameters
regGridSearch.best_estimator_
# Out:
# Lasso(alpha=0.1, max_iter=10000, normalize=True, precompute=True,
#       random_state=27, warm_start=True)

# %%
from sklearn.linear_model import Lasso

#Create a regression estimator with best parameters for cross validation
regEstimator = Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
                     normalize=True, positive=False, precompute=True, random_state=0,
                     selection='cyclic', tol=0.0001, warm_start=True)

#Evaluate the regression estimator above using our pre-defined cross validation and scoring metrics.
EvaluateRegressionEstimator(regEstimator, X, y, cv)
# Out:
# The average MAE for all cv folds is: 			 8.1159
# The average MAE percentage (MAPE) for all cv folds is: 	 55.018
# The average RMSE for all cv folds is: 			 10.188
# *********************************************************
# Cross Validation Fold Mean Error Scores
#         MAE       MAPE       RMSE
# 0  8.106642  51.686242  10.123861
# 1  8.665860  53.985575  10.860272
# 2  7.908318  62.926295  10.273921
# 3  8.085459  56.390257  10.258020
# 4  7.272222  51.431534   9.185548
# 5  8.135475  65.816441  10.170719
# 6  8.186034  50.719013  10.140205
# 7  8.810025  60.147092  10.934973
# 8  7.743327  44.691372   9.645102
# 9  8.245779  52.385990  10.283823

# %%
X = df_test.loc[:,df_test.columns != 'Score']
y = df_test['Score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = .2,random_state = 27)

# %%
from sklearn.metrics import mean_squared_error
import math

regEstimator.fit(X_train,y_train)
preds = regEstimator.predict(X_test)
MSE = mean_squared_error(y_test,preds)
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 9.567308879453542

# %%
preds.shape
# Out:
# (96,)

# %%
pd.options.display.max_rows = 480
preds = pd.DataFrame(regEstimator.predict(X))
preds
# Out:
#              0
# 0    24.840748
# 1    24.840748
# 2    24.508068
# 3    24.840748
# 4    24.840748
# 5    25.506109
# 6    25.173428
# 7    25.173428
# 8    24.508068
# 9    24.840748
# 10   24.508068
# 11   25.173428
# 12   24.508068
# 13   25.173428
# 14   23.842707
# 15   24.175387
# 16   24.840748
# 17   24.508068
# 18   24.175387
# 19   24.175387
# 20   25.173428
# 21   24.508068
# 22   24.175387
# 23   25.173428
# 24   23.842707
# 25   25.173428
# 26   24.175387
# 27   24.508068
# 28   24.840748
# 29   24.508068
# 30   25.506109
# 31   24.840748
# 32   24.508068
# 33   25.173428
# 34   24.840748
# 35   24.840748
# 36   24.840748
# 37   24.840748
# 38   24.508068
# 39   24.175387
# 40   24.508068
# 41   25.173428
# 42   25.173428
# 43   25.506109
# 44   24.840748
# 45   24.840748
# 46   25.173428
# 47   25.506109
# 48   24.840748
# 49   24.175387
# 50   24.508068
# 51   23.842707
# 52   24.840748
# 53   25.506109
# 54   24.840748
# 55   24.840748
# 56   25.173428
# 57   24.508068
# 58   25.838789
# 59   25.506109
# 60   24.175387
# 61   24.508068
# 62   23.842707
# 63   25.173428
# 64   24.508068
# 65   24.175387
# 66   24.840748
# 67   24.508068
# 68   25.173428
# 69   24.508068
# 70   24.508068
# 71   24.840748
# 72   24.840748
# 73   24.175387
# 74   24.508068
# 75   24.840748
# 76   24.508068
# 77   24.840748
# 78   23.842707
# 79   24.508068
# 80   24.508068
# 81   24.175387
# 82   24.508068
# 83   24.508068
# 84   24.175387
# 85   24.508068
# 86   24.840748
# 87   25.173428
# 88   24.840748
# 89   25.506109
# 90   24.175387
# 91   24.840748
# 92   24.508068
# 93   24.840748
# 94   23.842707
# 95   24.840748
# 96   25.173428
# 97   25.173428
# 98   24.175387
# 99   23.842707
# 100  24.508068
# 101  24.175387
# 102  24.175387
# 103  24.840748
# 104  25.173428
# 105  23.842707
# 106  25.506109
# 107  25.173428
# 108  25.506109
# 109  24.840748
# 110  24.175387
# 111  25.173428
# 112  23.842707
# 113  24.175387
# 114  24.508068
# 115  24.840748
# 116  25.506109
# 117  25.173428
# 118  24.508068
# 119  24.175387
# 120  24.508068
# 121  25.173428
# 122  24.175387
# 123  24.508068
# 124  25.173428
# 125  24.175387
# 126  23.842707
# 127  23.842707
# 128  24.175387
# 129  24.508068
# 130  24.175387
# 131  24.508068
# 132  24.840748
# 133  25.506109
# 134  25.173428
# 135  24.508068
# 136  24.175387
# 137  24.175387
# 138  25.173428
# 139  23.842707
# 140  24.175387
# 141  25.173428
# 142  24.840748
# 143  23.842707
# 144  24.508068
# 145  23.842707
# 146  24.175387
# 147  24.508068
# 148  24.175387
# 149  24.175387
# 150  24.508068
# 151  24.840748
# 152  24.508068
# 153  24.840748
# 154  25.173428
# 155  24.508068
# 156  24.840748
# 157  24.508068
# 158  24.840748
# 159  23.842707
# 160  24.508068
# 161  25.173428
# 162  24.840748
# 163  24.508068
# 164  24.175387
# 165  25.506109
# 166  25.173428
# 167  25.173428
# 168  24.840748
# 169  24.175387
# 170  25.506109
# 171  24.508068
# 172  25.173428
# 173  24.840748
# 174  25.173428
# 175  25.506109
# 176  24.840748
# 177  25.173428
# 178  24.840748
# 179  25.173428
# 180  24.508068
# 181  24.175387
# 182  24.840748
# 183  24.508068
# 184  24.840748
# 185  24.840748
# 186  24.508068
# 187  24.840748
# 188  24.175387
# 189  24.840748
# 190  24.840748
# 191  24.508068
# 192  24.175387
# 193  24.508068
# 194  25.173428
# 195  24.508068
# 196  24.508068
# 197  25.173428
# 198  24.175387
# 199  24.508068
# 200  25.173428
# 201  24.840748
# 202  24.175387
# 203  25.173428
# 204  24.508068
# 205  24.508068
# 206  24.840748
# 207  25.506109
# 208  24.840748
# 209  24.840748
# 210  24.840748
# 211  24.840748
# 212  24.175387
# 213  24.175387
# 214  24.508068
# 215  24.175387
# 216  24.175387
# 217  24.175387
# 218  24.508068
# 219  23.842707
# 220  24.175387
# 221  24.175387
# 222  24.175387
# 223  24.508068
# 224  24.508068
# 225  25.173428
# 226  23.842707
# 227  25.173428
# 228  24.508068
# 229  24.840748
# 230  24.508068
# 231  25.173428
# 232  25.506109
# 233  24.840748
# 234  25.506109
# 235  24.840748
# 236  24.175387
# 237  25.173428
# 238  24.840748
# 239  24.508068
# 240  24.175387
# 241  24.508068
# 242  24.175387
# 243  25.173428
# 244  24.840748
# 245  24.840748
# 246  24.840748
# 247  24.508068
# 248  24.840748
# 249  25.173428
# 250  23.842707
# 251  23.842707
# 252  24.508068
# 253  24.840748
# 254  24.175387
# 255  24.508068
# 256  25.173428
# 257  24.840748
# 258  24.508068
# 259  24.840748
# 260  24.175387
# 261  24.840748
# 262  24.508068
# 263  24.508068
# 264  24.840748
# 265  24.508068
# 266  25.506109
# 267  24.840748
# 268  24.508068
# 269  23.842707
# 270  25.173428
# 271  25.173428
# 272  24.508068
# 273  24.508068
# 274  25.173428
# 275  24.508068
# 276  24.175387
# 277  25.173428
# 278  25.173428
# 279  25.173428
# 280  23.842707
# 281  25.173428
# 282  24.840748
# 283  24.840748
# 284  24.175387
# 285  23.842707
# 286  24.508068
# 287  25.173428
# 288  23.842707
# 289  25.173428
# 290  24.840748
# 291  25.173428
# 292  25.173428
# 293  24.508068
# 294  24.175387
# 295  24.508068
# 296  24.175387
# 297  24.840748
# 298  24.508068
# 299  24.508068
# 300  24.175387
# 301  23.842707
# 302  24.840748
# 303  25.173428
# 304  24.508068
# 305  24.175387
# 306  25.173428
# 307  25.173428
# 308  24.175387
# 309  25.173428
# 310  24.508068
# 311  24.175387
# 312  23.842707
# 313  24.840748
# 314  24.840748
# 315  25.173428
# 316  24.840748
# 317  24.840748
# 318  25.506109
# 319  24.840748
# 320  24.840748
# 321  24.508068
# 322  25.506109
# 323  24.840748
# 324  24.840748
# 325  25.173428
# 326  24.840748
# 327  24.840748
# 328  24.840748
# 329  26.171470
# 330  24.840748
# 331  24.840748
# 332  24.840748
# 333  24.175387
# 334  23.842707
# 335  23.842707
# 336  24.175387
# 337  24.840748
# 338  24.508068
# 339  24.508068
# 340  24.508068
# 341  25.838789
# 342  23.842707
# 343  23.842707
# 344  23.842707
# 345  24.175387
# 346  24.175387
# 347  23.842707
# 348  23.842707
# 349  24.508068
# 350  24.508068
# 351  24.840748
# 352  24.508068
# 353  24.508068
# 354  24.840748
# 355  24.175387
# 356  23.842707
# 357  24.175387
# 358  23.842707
# 359  24.175387
# 360  24.508068
# 361  24.175387
# 362  24.175387
# 363  24.175387
# 364  24.175387
# 365  23.842707
# 366  24.175387
# 367  23.842707
# 368  24.840748
# 369  24.508068
# 370  23.842707
# 371  24.508068
# 372  23.842707
# 373  24.508068
# 374  24.508068
# 375  24.508068
# 376  24.175387
# 377  24.508068
# 378  24.508068
# 379  24.840748
# 380  23.842707
# 381  24.175387
# 382  24.175387
# 383  23.842707
# 384  24.508068
# 385  23.842707
# 386  24.175387
# 387  24.840748
# 388  24.508068
# 389  24.508068
# 390  24.508068
# 391  24.840748
# 392  24.508068
# 393  25.506109
# 394  25.506109
# 395  24.840748
# 396  25.173428
# 397  23.842707
# 398  24.840748
# 399  24.840748
# 400  24.175387
# 401  24.508068
# 402  24.175387
# 403  24.508068
# 404  25.173428
# 405  25.506109
# 406  25.506109
# 407  25.173428
# 408  25.173428
# 409  24.840748
# 410  25.173428
# 411  25.173428
# 412  25.173428
# 413  24.175387
# 414  24.508068
# 415  24.508068
# 416  24.175387
# 417  25.173428
# 418  24.508068
# 419  24.508068
# 420  24.508068
# 421  25.173428
# 422  24.840748
# 423  24.508068
# 424  24.508068
# 425  24.840748
# 426  24.840748
# 427  24.840748
# 428  24.508068
# 429  24.175387
# 430  24.508068
# 431  24.840748
# 432  24.175387
# 433  24.840748
# 434  24.508068
# 435  24.508068
# 436  25.173428
# 437  24.508068
# 438  25.506109
# 439  24.175387
# 440  25.506109
# 441  25.838789
# 442  24.175387
# 443  23.842707
# 444  25.173428
# 445  24.840748
# 446  24.840748
# 447  24.508068
# 448  25.173428
# 449  25.506109
# 450  24.175387
# 451  24.840748
# 452  24.175387
# 453  25.838789
# 454  25.173428
# 455  24.840748
# 456  24.508068
# 457  24.840748
# 458  24.508068
# 459  24.175387
# 460  25.838789
# 461  24.840748
# 462  25.173428
# 463  25.506109
# 464  24.508068
# 465  24.840748
# 466  23.842707
# 467  24.508068
# 468  24.508068
# 469  24.175387
# 470  24.175387
# 471  24.508068
# 472  24.508068
# 473  24.840748
# 474  24.508068
# 475  25.506109
# 476  24.508068
# 477  24.508068
# 478  23.842707
# 479  24.175387

# %%
preds.to_csv('data.csv')

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso

# %%
pipeline = Pipeline([
                     ('scaler',StandardScaler()),
                     ('model',Lasso())
])

# %%
search = GridSearchCV(pipeline,
                      {'model__alpha':np.arange(0.1,10,0.1)},
                      cv = 5, scoring="neg_mean_squared_error",verbose=3
                      )

# %%
search.fit(X_train,y_train)

# %%
search.best_params_

# %%
coefficients = search.best_estimator_.named_steps['model'].coef_

# %%
importance = np.abs(coefficients)
features = X.columns.values

# %%
np.array(features)[importance > 0]

# %%
np.array(features)[importance == 0]
